# %%
#import necessary modules to extract the Raw Data

import pandas as pd
import numpy as np
# to import Raw data in json format, we need below two modules
# import requests
# import json

# %%
# %%time

# read csv files from the site

df1 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data1.csv')
df1.head()
# Out:
# Wall time: 6.41 s
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0             1.0             KL-TS-P1     30/01/2020                   NaN
# 1             2.0             KL-AL-P1     02/02/2020                   NaN
# 2             3.0             KL-KS-P1     03/02/2020                   NaN
# 3             4.0                DL-P1     02/03/2020                   NaN
# 4             5.0                TS-P1     02/03/2020                   NaN
#
#   Age Bracket Gender             Detected City Detected District  \
# 0          20      F                  Thrissur          Thrissur
# 1         NaN    NaN                 Alappuzha         Alappuzha
# 2         NaN    NaN                 Kasaragod         Kasaragod
# 3          45      M  East Delhi (Mayur Vihar)        East Delhi
# 4          24      M                 Hyderabad         Hyderabad
#
#   Detected State State code  ...  \
# 0         Kerala         KL  ...
# ...

# %%
df1.shape
# Out:
# (17364, 21)

# %%
# %%time

df2 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data2.csv')
df3 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data3.csv')
df4 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data4.csv')
df5 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data5.csv')
df6 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data6.csv')
df7 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data7.csv')
df8 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data8.csv')
df9 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data9.csv')
df10 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data10.csv')
df11= pd.read_csv('https://api.covid19india.org/csv/latest/raw_data11.csv')
df12 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data12.csv')
df13 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data13.csv')
df14 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data14.csv')
df15 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data15.csv')
df16 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data16.csv')
df17 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data17.csv')
df18 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data18.csv')
df19 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data19.csv')
df20 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data20.csv')
df21 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data21.csv')
df22 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data22.csv')
df23 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data23.csv')
df24 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data24.csv')
df25 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data25.csv')
df26 = pd.read_csv('https://api.covid19india.org/csv/latest/raw_data26.csv')
# Out:
# Wall time: 1min 21s

# %%
# lets get an overview of our dataset

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             17306 non-null  float64
#  1   State Patient Number                       2457 non-null   object
#  2   Date Announced                             17364 non-null  object
#  3   Estimated Onset Date                       0 non-null      float64
#  4   Age Bracket                                1670 non-null   object
#  5   Gender                                     3746 non-null   object
#  6   Detected City                              2166 non-null   object
#  7   Detected District                          14978 non-null  object
#  8   Detected State                             17363 non-null  object
#  9   State code                                 17363 non-null  object
# ...

# %% [markdown]
# ## Now let's see if all the column names in each table are same or not before merging all the receords into single dataset: -

# %%
df1.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df7.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df8.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df9.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df10.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df15.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df22.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df26.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %% [markdown]
# ### Here we can see that all the column names from df1 till df26 has same column names but change in order which is alright.
#
# But if there are any columns names of a dataset not macthing with the columns name of another daatset, we will have to rename the name of the necessary columns to avoid confusion before merging.
#
# For this we can use the Rename function in Python
# SYNTAX: - data.rename(columns = {"current name" : "rename"})
#
# For ex: - dfn = dfn.rename(columns = {"curr_colName_like_Num cases" : "replace_colName_like_Num Cases"})

# %% [markdown]
# # Retain necessary Columns only:
# Once we have checked the col names now let us use only the required columns for our Interpretation and Analysis.

# %%
df1 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df2 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df3 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df4 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df5 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df6 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df7 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df8 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df9 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df10 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df11 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df12 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df13 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df14 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df15 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df16 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df17 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df18 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df19 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df20 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df21 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df22 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df23 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df24 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df25 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]
df26 = df1.loc[:, ['Num Cases', 'Date Announced', 'Age Bracket', 'Gender', 'Detected City', 'Detected District', 'Detected State', 'Current Status', ]]

# %%
df1.head()
# Out:
#    Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0          1     30/01/2020          20      F                  Thrissur
# 1          1     02/02/2020         NaN    NaN                 Alappuzha
# 2          1     03/02/2020         NaN    NaN                 Kasaragod
# 3          1     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4          1     02/03/2020          24      M                 Hyderabad
#
#   Detected District Detected State Current Status
# 0          Thrissur         Kerala      Recovered
# 1         Alappuzha         Kerala      Recovered
# 2         Kasaragod         Kerala      Recovered
# 3        East Delhi          Delhi      Recovered
# 4         Hyderabad      Telangana      Recovered

# %% [markdown]
# ## Merging all the datasets:

# %%
df = df1.append([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, 
                 df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26])
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0              1     30/01/2020          20      F                  Thrissur
# 1              1     02/02/2020         NaN    NaN                 Alappuzha
# 2              1     03/02/2020         NaN    NaN                 Kasaragod
# 3              1     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4              1     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 17359         -2     16/04/2020         NaN    NaN                       NaN
# 17360          1     18/04/2020         NaN    NaN                       NaN
# 17361         -1     18/04/2020         NaN    NaN                       NaN
# 17362         10     19/04/2020         NaN    NaN                       NaN
# 17363        -10     19/04/2020         NaN    NaN                       NaN
#
# ...

# %% [markdown]
# ## For Analysis purpose we can split our Date Announced to -> Day, Month, Year

# %%
Date = df['Date Announced'].str.split('/', expand = True)
Date.columns = ['Day', 'Month', 'Year']
Date
# Out:
#       Day Month  Year
# 0      30    01  2020
# 1      02    02  2020
# 2      03    02  2020
# 3      02    03  2020
# 4      02    03  2020
# ...    ..   ...   ...
# 17359  16    04  2020
# 17360  18    04  2020
# 17361  18    04  2020
# 17362  19    04  2020
# 17363  19    04  2020
#
# [468828 rows x 3 columns]

# %% [markdown]
# ### Concatenate Date with our data:

# %%
df = pd.concat([df, Date], axis = 1)
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0              1     30/01/2020          20      F                  Thrissur
# 1              1     02/02/2020         NaN    NaN                 Alappuzha
# 2              1     03/02/2020         NaN    NaN                 Kasaragod
# 3              1     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4              1     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 17359         -2     16/04/2020         NaN    NaN                       NaN
# 17360          1     18/04/2020         NaN    NaN                       NaN
# 17361         -1     18/04/2020         NaN    NaN                       NaN
# 17362         10     19/04/2020         NaN    NaN                       NaN
# 17363        -10     19/04/2020         NaN    NaN                       NaN
#
# ...

# %% [markdown]
# # Lets us export all of these into a CSV file now

# %%
df.to_csv('COVID19INDIA_CAPSTPROJECT.csv')

# %%
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0              1     30/01/2020          20      F                  Thrissur
# 1              1     02/02/2020         NaN    NaN                 Alappuzha
# 2              1     03/02/2020         NaN    NaN                 Kasaragod
# 3              1     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4              1     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 17359         -2     16/04/2020         NaN    NaN                       NaN
# 17360          1     18/04/2020         NaN    NaN                       NaN
# 17361         -1     18/04/2020         NaN    NaN                       NaN
# 17362         10     19/04/2020         NaN    NaN                       NaN
# 17363        -10     19/04/2020         NaN    NaN                       NaN
#
# ...
